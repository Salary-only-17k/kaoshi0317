# %% [markdown]
# ## 任务一 除草行动
# 任务描述：霸道总裁Lady家有个1000m\*1000m的院子，有些地方种了树，有些地方长了草。她通过某种高科技产品，扫描了她的院子，决定将那些不到100cm的植物铲除。于是她设计了一个装载着GPU的除草机器人，想请第四届CUDA on ARM platform夏令营的同学们帮她设计一个算法，来判断哪些位置的植物高度小于100cm。
# 详细描述：输入一个1000\*1000的矩阵，对矩阵中的每一个元素进行判断，如果元素值小于100，则将该元素值修改为0，如果该元素值大于100，则将该元素值修改为1。具体代码，请参考1.cu
# 任务难度：D
# 前置资源：框架代码一份
# 要求：完成代码框架，得到输出
# 任务奖惩:
# 成功奖励: NVIDIA的CUDA on ARM课程证书 1/3份
# 失败惩罚: 补考群7日游
#
# ## 任务二 Lady家的画
# 任务描述：霸道总裁Lady在除完草之后，在院子里又种了一些树。作为一个报道总裁，她对画画情有独钟。于是，她利用这些树在院子里组成了一幅画。但是由于她家的花匠欢欢的疏忽，将树种错了，让整幅画沿对角线组合反了。于是，Lady想请第四届CUDA on ARM platform夏令营的同学们将画沿对角线进行调整。
# 详细描述：输入一个1000\*1000的矩阵，将矩阵进行转置。
# 任务难度：B
# 前置资源：代码框架一份
# 要求：利用CUDA加速矩阵转置操作，输入为一个1000x1000的方阵，输出为该方阵的转置矩阵。下图所示为一个3x3的矩阵的转置。
# 任务奖惩: 成功奖励: NVIDIA的CUDA on ARM课程证书 1/3份
# 失败惩罚: 补考群7日游
# ![matrix_T.png](matrix_T.jpg)
#
#
# ## 任务三 张三丰的方圆之道
# 任务描述:
# 武当张三丰潜心研究太极拳,  在连续画圆几十年后, 成功领悟了物理/数学不分家的道理. 现在他决定用自己强悍的臂力, 以蒙特卡洛法, 在一个2001米 * 2001米的场地内进行真随机投掷7公斤重的铅球10W次. 以求得数学中的究极魔法数字Pi的近似值.
# Ken听闻此事后, 大为老人的精神感动, 决定带领第三届的同学们, 用GPU替他完成统计计算.
# 现在需要勇敢的你继续去完张三丰的未竟事业, 铅球的落点坐标, Ken老师已经为你整理成2D数组的形式.
#
# 详细描述：利用蒙特卡洛法求取圆周率Pi值。在一个正方形内，真随机投掷一个小球，计算小球与正方形正中心的距离，如果小于圆的半径我们则认为球在圆内。那么就可以利用在圆内球的个数I 和在总的球的个数N求出圆周率Pi = （4\*I)/N
# 具体代码请参考3.cu
#
# 任务难度: B
# 前置资源: 1x 未完成的代码框架, 1x公式: Pi = 落在大方形的内切圆中的铅球数量 / 2500.
# 要求: 完成框架, 得到Pi的近似值(不能偏差1%以上).
# 任务奖惩:
# 成功奖励: NVIDIA的CUDA on ARM课程证书 的最后1/3部分
# 失败惩罚: 补考群7日游
